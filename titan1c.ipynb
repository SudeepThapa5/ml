# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(), cmap = "bwr")
# Out:
# <Axes: >

# %%
sns.countplot(x="Survived",data = df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",data = df, hue = "Sex")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",data = df, hue = "Embarked")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
## EDA ##

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.isnull().Pclass.sum()
# Out:
# np.int64(0)

# %%
df.isnull().Sex.sum()
# Out:
# np.int64(0)

# %%
df.isnull().Age.sum()
# Out:
# np.int64(177)

# %%
age_mean = df.Age.mean().astype(int)
age_mean
# Out:
# np.int64(29)

# %%
df.fillna({"Age" : age_mean}, inplace = True)

# %%
df.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().Embarked.sum()
# Out:
# np.int64(2)

# %%
em_mode = df.Embarked.mode()[0]

# %%
df.fillna({"Embarked" : em_mode }, inplace = True)

# %%
df.isnull().Embarked.sum()
# Out:
# np.int64(0)

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age            Ticket     Fare  \
# 0              1         0       3    male  22.0         A/5 21171   7.2500
# 1              2         1       1  female  38.0          PC 17599  71.2833
# 2              3         1       3  female  26.0  STON/O2. 3101282   7.9250
# 3              4         1       1  female  35.0            113803  53.1000
# 4              5         0       3    male  35.0            373450   8.0500
# ..           ...       ...     ...     ...   ...               ...      ...
# 886          887         0       2    male  27.0            211536  13.0000
# 887          888         1       1  female  19.0            112053  30.0000
# 888          889         0       3  female  29.0        W./C. 6607  23.4500
# 889          890         1       1    male  26.0            111369  30.0000
# 890          891         0       3    male  32.0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# ...

# %%
df.sort_values( by ="Pclass", ascending = True)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age            Ticket     Fare  \
# 857          858         1       1    male  51.0            113055  26.5500
# 862          863         1       1  female  48.0             17466  25.9292
# 867          868         0       1    male  31.0          PC 17590  50.4958
# 52            53         1       1  female  49.0          PC 17572  76.7292
# 839          840         1       1    male  29.0             11774  29.7000
# ..           ...       ...     ...     ...   ...               ...      ...
# 4              5         0       3    male  35.0            373450   8.0500
# 888          889         0       3  female  29.0        W./C. 6607  23.4500
# 2              3         1       3  female  26.0  STON/O2. 3101282   7.9250
# 890          891         0       3    male  32.0            370376   7.7500
# 0              1         0       3    male  22.0         A/5 21171   7.2500
#
#     Cabin Embarked
# 857   E17        S
# ...

# %%
df.Sex = df.Sex.str.capitalize()

# %%
df.Sex
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3      Female
# 4        Male
#         ...
# 886      Male
# 887    Female
# 888    Female
# 889      Male
# 890      Male
# Name: Sex, Length: 891, dtype: object
